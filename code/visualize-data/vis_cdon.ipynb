# %%
import numpy as np               # Array manipulation
import pandas as pd              # Data Manipulation
import matplotlib.pyplot as plt  # Plotting
import seaborn as sns            # Statistical plotting

# %% [markdown]
# Load the data and test

# %%
_data = np.sort(np.fromfile('data_cdon.dat', dtype=int))
_data
# Out:
# array([   66,    66,    66, ..., 18613, 19026, 19660])

# %% [markdown]
# Define Style and Context

# %%
sns.set_style('white')
sns.set_context("paper", font_scale = 2)

# %% [markdown]
# Plot the data

# %%
sns.displot(data=_data, kind="hist", kde=True, aspect = 1.5)
